# %% [markdown]
# ### Import required projects

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
retail = pd.read_csv(r"C:\Users\vijay\OneDrive\Desktop\Eletive labs intenrnship\1st week Projects-1\retail_business_performance_dataset.csv")
retail.head(3)
# Out:
#    Order_ID   Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 0        63    Grocery        Dairy   East  Spring        12      887.75
# 1       170   Clothing          Men  North  Spring        40      236.74
# 2       131  Furniture       Tables   East  Spring         6      497.69
#
#    Discount  Cost_Price   Revenue   Profit  Order_Date
# 0      0.01      686.82  10546.47  2304.63  2024-10-14
# 1      0.16      172.69   7954.46  1046.86  2024-03-07
# 2      0.10      393.19   2687.53   328.39  2024-08-27

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      220 non-null    int64
#  1   Category      209 non-null    object
#  2   Sub_Category  215 non-null    object
#  3   Region        209 non-null    object
#  4   Season        220 non-null    object
#  5   Quantity      220 non-null    int64
#  6   Unit_Price    220 non-null    float64
#  7   Discount      209 non-null    float64
#  8   Cost_Price    220 non-null    float64
#  9   Revenue       220 non-null    float64
#  10  Profit        209 non-null    float64
#  11  Order_Date    220 non-null    object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 20.8+ KB

# %%
# Here convert order date
retail['Order_Date'] = pd.to_datetime(retail['Order_Date'])
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      220 non-null    int64
#  1   Category      209 non-null    object
#  2   Sub_Category  215 non-null    object
#  3   Region        209 non-null    object
#  4   Season        220 non-null    object
#  5   Quantity      220 non-null    int64
#  6   Unit_Price    220 non-null    float64
#  7   Discount      209 non-null    float64
#  8   Cost_Price    220 non-null    float64
#  9   Revenue       220 non-null    float64
#  10  Profit        209 non-null    float64
#  11  Order_Date    220 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(2), object(4)
# memory usage: 20.8+ KB

# %%
# find the null values 
retail.isnull().sum()
# Out:
# Order_ID         0
# Category        11
# Sub_Category     5
# Region          11
# Season           0
# Quantity         0
# Unit_Price       0
# Discount        11
# Cost_Price       0
# Revenue          0
# Profit          11
# Order_Date       0
# dtype: int64

# %% [markdown]
# - Here I impute the values if there is categoeical column impute **Mode** method and there is numerical value **mean** method
# - Is there is an date and time null values using **forward fill** and **backword method**

# %%
category_mode = retail['Category'].mode()[0]
retail['Category'].fillna(category_mode,inplace=True)

# %%
sub_category_mode = retail['Sub_Category'].mode()[0]
retail['Sub_Category'].fillna(sub_category_mode,inplace=True)
import warnings
warnings.filterwarnings('ignore')

# %%
region_mode = retail['Region'].mode()[0]
retail['Region'].fillna(region_mode,inplace=True)

# %% [markdown]
# **Numerical columns**

# %%
dis_mean = retail['Discount'].mean()
retail['Discount'].fillna(dis_mean,inplace=True)
retail[retail['Discount']==dis_mean]
# Out:
#      Order_ID     Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 5           6  Electronics      Laptops   East  Autumn        16      240.44
# 20         20     Clothing        Women  South  Spring        40      281.97
# 99         40      Grocery       Snacks   East  Autumn        39      937.36
# 109        32     Clothing        Women   West  Autumn        12      259.26
# 116       214  Electronics      Laptops   West  Autumn        41      281.31
# 133        81      Grocery    Beverages  South  Summer        33      813.09
# 144       212  Electronics      Mobiles   East  Winter        46      984.56
# 163       168      Grocery        Dairy  North  Autumn        40      383.17
# 183       137     Clothing          Men  South  Autumn        34      137.46
# 206       139     Clothing        Women   West  Autumn        48       70.47
# 208       209      Grocery          TVs   West  Summer        44      148.71
#
# ...

# %%
median_profit = retail['Profit'].median()
retail['Profit'].fillna(median_profit,inplace=True)

# %%
retail.isnull().sum()
# Out:
# Order_ID        0
# Category        0
# Sub_Category    0
# Region          0
# Season          0
# Quantity        0
# Unit_Price      0
# Discount        0
# Cost_Price      0
# Revenue         0
# Profit          0
# Order_Date      0
# dtype: int64

# %%
retail.head(2)
# Out:
#    Order_ID  Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 0        63   Grocery        Dairy   East  Spring        12      887.75
# 1       170  Clothing          Men  North  Spring        40      236.74
#
#    Discount  Cost_Price   Revenue   Profit Order_Date
# 0      0.01      686.82  10546.47  2304.63 2024-10-14
# 1      0.16      172.69   7954.46  1046.86 2024-03-07

# %%
## drop duplicates 
retail.drop_duplicates(inplace=True)

# %%
retail.shape
# Out:
# (220, 12)

# %% [markdown]
# - Here the columns has **no duplicate** values
# - we have **220 rows** and **12 columns**

# %%
# correltion

# %%
cor =retail.corr(numeric_only=True)
cor
# Out:
#             Order_ID  Quantity  Unit_Price  Discount  Cost_Price   Revenue  \
# Order_ID    1.000000 -0.000027   -0.075573  0.118777   -0.083589 -0.067101
# Quantity   -0.000027  1.000000   -0.046711  0.130638   -0.029020  0.628052
# Unit_Price -0.075573 -0.046711    1.000000 -0.010186    0.975296  0.643261
# Discount    0.118777  0.130638   -0.010186  1.000000    0.004757 -0.025449
# Cost_Price -0.083589 -0.029020    0.975296  0.004757    1.000000  0.643424
# Revenue    -0.067101  0.628052    0.643261 -0.025449    0.643424  1.000000
# Profit     -0.000434  0.231708    0.234673 -0.458683    0.111711  0.449073
#
#               Profit
# Order_ID   -0.000434
# Quantity    0.231708
# Unit_Price  0.234673
# Discount   -0.458683
# Cost_Price  0.111711
# Revenue     0.449073
# Profit      1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cor,annot=True,color='Blue')
# Out:
# <Axes: >

# %% [markdown]
# ### bar chart: Region by profit

# %%
keys =retail['Region'].value_counts().keys()
values = retail['Region'].value_counts().values
plt.figure(figsize=(8,8))
plt.bar(keys,values)
plt.title("Region & There Count")
plt.xlabel("Region")
plt.ylabel("count")
plt.show()

# %%
retail.head(3)
# Out:
#    Order_ID   Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 0        63    Grocery        Dairy   East  Spring        12      887.75
# 1       170   Clothing          Men  North  Spring        40      236.74
# 2       131  Furniture       Tables   East  Spring         6      497.69
#
#    Discount  Cost_Price   Revenue   Profit Order_Date
# 0      0.01      686.82  10546.47  2304.63 2024-10-14
# 1      0.16      172.69   7954.46  1046.86 2024-03-07
# 2      0.10      393.19   2687.53   328.39 2024-08-27

# %%
# univariate and bivariate 
col1=retail['Region']
col2 = retail['Season']

analysis1 =pd.crosstab(col1,col2)
analysis1
# Out:
# Season  Autumn  Spring  Summer  Winter
# Region
# East        13      10      11      13
# North       17      11       8      12
# South       14      19      24      21
# West        17      10       7      13

# %%
analysis1.plot(kind='bar',label=True)
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# ## pie chart

# %%
retail.head(3)
# Out:
#    Order_ID   Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 0        63    Grocery        Dairy   East  Spring        12      887.75
# 1       170   Clothing          Men  North  Spring        40      236.74
# 2       131  Furniture       Tables   East  Spring         6      497.69
#
#    Discount  Cost_Price   Revenue   Profit Order_Date
# 0      0.01      686.82  10546.47  2304.63 2024-10-14
# 1      0.16      172.69   7954.46  1046.86 2024-03-07
# 2      0.10      393.19   2687.53   328.39 2024-08-27

# %%
keys = retail['Category'].value_counts().keys()
values = retail['Category'].value_counts().values
plt.figure(figsize=(8,5))

plt.pie(values,labels=keys,autopct='%1.2f%%',shadow=True,startangle=90)
plt.title("Percentage of Category")
plt.show()

# %% [markdown]
# - the figure shows the category all items **Grocery** is the highest and lowest **Toys and Clothing**

# %% [markdown]
# - Problem statement:In category column which are sub part of sub_Category

# %%
retail.head(2)
# Out:
#    Order_ID  Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 0        63   Grocery        Dairy   East  Spring        12      887.75
# 1       170  Clothing          Men  North  Spring        40      236.74
#
#    Discount  Cost_Price   Revenue   Profit Order_Date
# 0      0.01      686.82  10546.47  2304.63 2024-10-14
# 1      0.16      172.69   7954.46  1046.86 2024-03-07

# %%
col2=retail['Region']
col1 =retail['Category']


analyed = pd.crosstab(col1,col2,)
analyed
# Out:
# Region       East  North  South  West
# Category
# Clothing        6     10     12     8
# Electronics    11     11     13     9
# Furniture       6     10     19    11
# Grocery        16     12     16    14
# Toys            8      5     18     5

# %%
plt.figure(figsize=(10,10))
analyed.plot(kind='bar')
plt.title("Category with region")
plt.show()

# %% [markdown]
# **Above bar graph showing the category and their regions**
#
# - In clothing category south region is highest and East region is low
# - In Electronics category south Rehion is high and west Region is low
# - In Furniture category south Region is high and East Region is low
# - In Grocery category East & and south regions are same and North is low
# - In Toys category South region is high and West region is low

# %%
retail.head(2)
# Out:
#    Order_ID  Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 0        63   Grocery        Dairy   East  Spring        12      887.75
# 1       170  Clothing          Men  North  Spring        40      236.74
#
#    Discount  Cost_Price   Revenue   Profit Order_Date
# 0      0.01      686.82  10546.47  2304.63 2024-10-14
# 1      0.16      172.69   7954.46  1046.86 2024-03-07

# %%
c=retail['Profit']
retail[retail['Profit']<0]
# Out:
#      Order_ID     Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 8          54      Grocery       Snacks  North  Summer        44      941.05
# 10         61      Grocery    Beverages  North  Summer        26      812.01
# 12        201  Electronics      Laptops   East  Summer        47      573.75
# 44         57    Furniture       Chairs  South  Summer         3      177.80
# 46        115  Electronics  Accessories  South  Spring        25      424.06
# 51         33      Grocery       Indoor   East  Spring        17      274.11
# 54         70    Furniture       Chairs   West  Winter        26       35.10
# 59         86  Electronics      Laptops  North  Autumn        29       48.79
# 67        161  Electronics  Accessories   West  Autumn        20      262.09
# 74        155    Furniture       Chairs   West  Autumn        38      671.96
# 77         90      Grocery        Dairy   West  Spring        35      112.09
# ...

# %%
plt.scatter(retail['Quantity'],retail['Profit'])

# %% [markdown]
# - some products get loss profit and some products got profit gain

# %%
r1=retail.groupby('Region')['Profit'].sum().keys()
r2 = retail.groupby('Region')['Profit'].sum().values
plt.figure(figsize=(5,5))
plt.bar(r1,r2,color='Green')
plt.title("Total profit by region")
plt.xlabel("Region")
plt.ylabel("Sum of Profit")
plt.show()

# %% [markdown]
# - Here South Region has Highest profit ans west region has lowerst profit

# %%
retail.head(3)
# Out:
#    Order_ID   Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 0        63    Grocery        Dairy   East  Spring        12      887.75
# 1       170   Clothing          Men  North  Spring        40      236.74
# 2       131  Furniture       Tables   East  Spring         6      497.69
#
#    Discount  Cost_Price   Revenue   Profit Order_Date
# 0      0.01      686.82  10546.47  2304.63 2024-10-14
# 1      0.16      172.69   7954.46  1046.86 2024-03-07
# 2      0.10      393.19   2687.53   328.39 2024-08-27

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      220 non-null    int64
#  1   Category      220 non-null    object
#  2   Sub_Category  220 non-null    object
#  3   Region        220 non-null    object
#  4   Season        220 non-null    object
#  5   Quantity      220 non-null    int64
#  6   Unit_Price    220 non-null    float64
#  7   Discount      220 non-null    float64
#  8   Cost_Price    220 non-null    float64
#  9   Revenue       220 non-null    float64
#  10  Profit        220 non-null    float64
#  11  Order_Date    220 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(2), object(4)
# memory usage: 20.8+ KB

# %% [markdown]
# - line plot Profit Trend Over Time .
# - Here Clearly some times profit growth and some times profit loss

# %%
plt.figure(figsize=(10,8))
plt.plot(retail['Order_Date'],retail['Profit'])
plt.xlabel("Order_date")
plt.ylabel("Profit")
plt.title('Profit Trend Over Time')
plt.show()

# %%
retail.head(3)
# Out:
#    Order_ID   Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 0        63    Grocery        Dairy   East  Spring        12      887.75
# 1       170   Clothing          Men  North  Spring        40      236.74
# 2       131  Furniture       Tables   East  Spring         6      497.69
#
#    Discount  Cost_Price   Revenue   Profit Order_Date
# 0      0.01      686.82  10546.47  2304.63 2024-10-14
# 1      0.16      172.69   7954.46  1046.86 2024-03-07
# 2      0.10      393.19   2687.53   328.39 2024-08-27

# %% [markdown]
# - finding the outliers profit
# - removing the outliers

# %%
plt.boxplot(retail['Profit'])
plt.show()

# %%
profit_data = retail['Profit']
q1 = np.percentile(profit_data,25)
q2 = np.percentile(profit_data,50)
q3 = np.percentile(profit_data,75)
Iqr = q3-q1
lower_boundary = q1 - 1.5*Iqr
upper_boundary = q3+1.5*Iqr
cond1 = profit_data <lower_boundary
cond2 = profit_data >upper_boundary
main_con = cond1|cond2
outlier_data = retail[main_con]
print(len(outlier_data))
outlier_df = pd.DataFrame(outlier_data)
outlier_df
# Out:
# 22
#      Order_ID     Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 8          54      Grocery       Snacks  North  Summer        44      941.05
# 10         61      Grocery    Beverages  North  Summer        26      812.01
# 11        184      Grocery       Snacks   West  Spring        41      926.31
# 22         56  Electronics  Accessories  South  Spring        35      980.53
# 32         45    Furniture         Beds  North  Summer        33      645.61
# 83        118  Electronics          TVs  South  Summer        27      573.39
# 86        106    Furniture       Tables  North  Winter        44      978.12
# 87         44      Grocery        Dairy   West  Spring        35      703.35
# 90         30    Furniture       Chairs  South  Summer        37      695.51
# 97         55     Clothing          Men   East  Winter        41      953.54
# 99         40      Grocery       Snacks   East  Autumn        39      937.36
# ...

# %% [markdown]
# - In the above dataset we have 22 outliers through the profit

# %%
profit_data = retail['Profit']
q1 = np.percentile(profit_data,25)
q2 = np.percentile(profit_data,50)
q3 = np.percentile(profit_data,75)
Iqr = q3-q1
lower_boundary = q1 - 1.5*Iqr
upper_boundary = q3+1.5*Iqr
cond1 = profit_data >lower_boundary
cond2 = profit_data <upper_boundary
main_con = cond1 & cond2
non_outlier_data = retail[main_con]
print(len(non_outlier_data))
non_outlier_df = pd.DataFrame(non_outlier_data)
non_outlier_df
# Out:
# 198
#      Order_ID     Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 0          63      Grocery        Dairy   East  Spring        12      887.75
# 1         170     Clothing          Men  North  Spring        40      236.74
# 2         131    Furniture       Tables   East  Spring         6      497.69
# 3         202         Toys       Indoor  South  Summer        34      807.26
# 4         185  Electronics      Laptops  South  Spring        46      194.46
# ..        ...          ...          ...    ...     ...       ...         ...
# 214       216         Toys       Indoor  South  Summer         6      734.86
# 215       213     Clothing          Men  South  Summer        37       28.21
# 216        13         Toys      Outdoor   East  Spring        15       97.61
# 218       133         Toys       Snacks  North  Winter        11      147.44
# 219       167    Furniture       Tables  South  Summer        25      878.43
#
# ...

# %%
sns.boxplot(non_outlier_data['Revenue'])
plt.show()

# %% [markdown]
# - removed outliers

# %% [markdown]
# **Lineplot order date trend over profit**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(x='Order_Date', y='Profit', data=retail)
plt.title("Order_Date Trend over Profit")
plt.xlabel("Order_Date")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# - Trend of sales month-wise?

# %%
retail['month'] = retail['Order_Date'].dt.month

# %%
retail.head(3)
# Out:
#    Order_ID   Category Sub_Category Region  Season  Quantity  Unit_Price  \
# 0        63    Grocery        Dairy   East  Spring        12      887.75
# 1       170   Clothing          Men  North  Spring        40      236.74
# 2       131  Furniture       Tables   East  Spring         6      497.69
#
#    Discount  Cost_Price   Revenue   Profit Order_Date  month
# 0      0.01      686.82  10546.47  2304.63 2024-10-14     10
# 1      0.16      172.69   7954.46  1046.86 2024-03-07      3
# 2      0.10      393.19   2687.53   328.39 2024-08-27      8

# %%
sns.lineplot(x='month',y='Profit',data=retail)
plt.show()

# %% [markdown]
# **Monthly_sales**

# %%
monthly_sales = retail.groupby('month')['Revenue'].sum()
monthly_sales
# Out:
# month
# 1     302095.38
# 2     185249.39
# 3     152742.23
# 4     238991.24
# 5     220349.59
# 6     170685.58
# 7     189699.65
# 8     225291.15
# 9      58783.74
# 10    335080.36
# 11    208695.36
# 12    195120.41
# Name: Revenue, dtype: float64

# %%
x=retail.groupby('month')['Revenue'].sum().keys()
y=retail.groupby('month')['Revenue'].sum().values
plt.bar(x,y)
plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Monthly Revenue")
plt.show()

# %% [markdown]
# - Here October month has highest sales
# - september has lowest sales and low revenue generated

# %% [markdown]
# **Group total sales by category**

# %%
category_sales = retail.groupby('Category')['Revenue'].sum()
print(category_sales)
# Out:
# Category
# Clothing       398792.00
# Electronics    474228.87
# Furniture      559610.81
# Grocery        720833.50
# Toys           329318.90
# Name: Revenue, dtype: float64

# %%
keys = retail.groupby('Category')['Revenue'].sum().keys()
values = category_sales = retail.groupby('Category')['Revenue'].sum().values
plt.barh(keys,values,color='Orange')
plt.title("Catergory sales over trend by revenue")
plt.xlabel("Category")
plt.ylabel("Sum of Revenue")
plt.show()

# %% [markdown]
# - Greocery has highest revenue
# - Toys has lowest reveune

# %%
retail=retail.to_csv("retail.csv",index=False)
